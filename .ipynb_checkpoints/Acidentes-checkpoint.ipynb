# %% [markdown]
# # Transito no Brasil, o que mudou em 10 anos?
#
# Inspirado pela analise do Gabriel Gomes no LinkedIn (https://goo.gl/v1ZVdJ) e após ter conversado com o mesmo, decidi analisar o mesmo conjunto de dados, mas ao invés de dar uma ênfase no perfil das vítimas, decidir extrair as repostas para minhas própias perguntas, que são:
#
# ##### Infos sobre os veículos envolvidos:
# 	- Veículos com maior numero de vitimas fatais
# 	- Veículos com maior numero de vitimas ilesas
# 	- Veículos com maior índice de falha mecânica
# 	- Veículos em que se envolveram em acidente por estar acima da velocidade regulamentada (top alguma coisa)
# 	- Veículos com maior numero de capotamentos (Hilux, cadê vc...?)
# 	- O ano do veículo influencia no estado das vítimas? (Os carros mais novos são mais seguros?)
#
# ##### Infos sobre Dia, clima, época do ano
# 	- Dia da semana com maior numero de ocorrencias
# 	- Estado das vítimas x dia da semana
# 	- Numero de ocorrências x hora do dia
# 	- Épocas do ano mais propensas à acidentes
# 	- Condições climáticas mais perigosas
# 	- Existe alguma relação entre a condição meteorológica x fase do dia e tipo de acidente?
#
# ##### Infos sobre o local do acidente
# 	- Estradas com maior número de vítimas (ilesas, feridos leves, feridos graves, e mortos)
# 	- Municípios com maior número de acidentes
# 	- O tipo de pista (Duplicada, Mão dupla, etc.) e o traçado da via tem relação com o tipo de acidente?
# 	- Tipo de pista x traçado da via x número e estado das vítimas
# 	- Heatmap neles!
#
# ##### Infos sobre as vítimas
# 	- A idade está relacionada com o estado da vítima de acordo com o tipo do acidente (Idade x Estado da vitima x Tipo do acidente)
# 	- Numero de acidentes e vítimas por sexo do condutor
#
# ##### Infos sobre o evento
# 	- Municípios com maior número de acidentes causados por ingestão de alcool
# 	- Tipo de acidente mais letal

# %% [markdown]
# Neste notebook irei tratar e explorar dados de 10 anos de registros (de 2008 a Out/2018) que foram consolidados em um arquivo .csv por processo de carga de dados em MS SQL Server e posterior exportação para arquivo .csv. Processo que pode ser acompanhado nestes links:
#
# #### Importação dos dados pro SQL Server
# https://www.linkedin.com/pulse/transito-brasil-o-que-mudou-em-10-anos-parte-1-ramon-nogueira/
#
# #### Exportação e pré processamento dos dados no Jupyter Lab
# https://www.linkedin.com/pulse/transito-brasil-o-que-mudou-em-10-anos-parte-2-limpeza-nogueira/

# %% [markdown]
# ### Sobre os dados
# Os dados utilizados para esta análise estão disponíveis no site da PRF (https://www.prf.gov.br/portal/dados-abertos/acidentes/acidentes) na sessão 'Agrupados por Pessoa'.
# Uma versão simples do dicionário destes dados está disponível no corpo do artigo : https://www.linkedin.com/pulse/transito-brasil-o-que-mudou-em-10-anos-parte-1-ramon-nogueira/

# %%
#Importação das bibliotecas utilizadas neste notebook

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Setando os plots para serem exibidos diretamente no notebook
# %matplotlib inline

# %%
#Importação dos dados.
#Detalhe para o atributo encoding que recebeu o parâmetro 'latin1' conforme setado na exportação dos dados do banco
#E o atributo low_memory que recebeu False como parâmetro para que os campos fossem lidos conforme consta no arquivo, de modo a evitar a tipagem de cada campo manualmente

#OBS: O import do arquivo demora por conta do parametro parse_dates, aceito sugestões p/ melhora da performace
rawdata = pd.read_csv('Acidentes_cons.csv', encoding='latin1', low_memory= False, parse_dates = ['data_inversa'])

# %%
rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3453255 entries, 0 to 3453254
# Data columns (total 38 columns):
# reg_id                    int64
# id                        object
# pesid                     float64
# data_inversa              datetime64[ns]
# dia_semana                object
# horario                   object
# uf                        object
# br                        object
# km                        object
# municipio                 object
# causa_acidente            object
# tipo_acidente             object
# classificacao_acidente    object
# fase_dia                  object
# sentido_via               object
# condicao_metereologica    object
# tipo_pista                object
# tracado_via               object
# uso_solo                  object
# id_veiculo                object
# tipo_veiculo              object
# marca                     object
# ano_fabricacao_veiculo    object
# tipo_envolvido            object
# ...

# %% [markdown]
# Ok, temos os dados já carregados em memória e agora poderemos dar início ao processo de exploração e tratamento destes dados. Existem alguns tratamentos que devem ser aplicados a toda massa de dados desconhecida, estes serão destacados com um * na lista de procedimentos que desejo realizar antes de começar a fazer o 'feature engeneering'
#
# #### Limpeza dos dados:
#     Checagem de valores nulos ou NaN * (de acordo com o dicionário que escrevi)
#     Checagem de inconsistências em valores numéricos * (idade -1, etc)
#     Checagem de inconsistências em valores de texto *
#     Descarte de registros com muitos valores NaN *
#     Limpeza dos valores de texto (se necessário)
#     Tipagem correta dos campos (Números inteiros como inteiros, valores quebrados como float, etc)
#     Exclusão de registros sem campos considerados chave, como município, causa_acidente, etc.
#     Descarte de campos marcados para exclusão (de acordo com dicionário de dados)
#
# Só depois de ter os dados limpos poderemos padronizar todo o dataset e aplicar lógicas afim de popular os campos ilesos, feridos_leves, feridos_graves e mortos (inseridos de 2017 pra frente) com os dados de 2008 a 2016. Feature Engeneering ou 'Engenharia de características' é o nome dado ao processo de utilizar os dados disponíveis para gerar novas informações afim de complementar o dataset

# %%
#Verificando valores nulos/nan em cada coluna
rawdata.isnull().sum()
# Out:
# reg_id                          0
# id                              0
# pesid                           3
# data_inversa                    1
# dia_semana                      1
# horario                         1
# uf                              1
# br                            543
# km                            543
# municipio                       1
# causa_acidente                  1
# tipo_acidente                   1
# classificacao_acidente          3
# fase_dia                        2
# sentido_via                     1
# condicao_metereologica          8
# tipo_pista                      1
# tracado_via                     1
# uso_solo                        1
# id_veiculo                   4000
# tipo_veiculo                 4003
# marca                       34014
# ano_fabricacao_veiculo      33707
# tipo_envolvido                  1
# estado_fisico                   4
# idade                       70739
# sexo                          681
# ...

# %%
#Salvando o número de linhas atual do dataset
antes = rawdata.shape[0]

#Dropando as colunas que não serão utilizadas
#OBS: nacionalidade e naturalidade seriam utilizadas mais adiante, mas visto o numero de registros em branco, acabei optando por descartar
rawdata.drop(labels= ['nacionalidade','naturalidade','regional','delegacia','uop'], axis = 1, inplace = True)

#Dropando os registros que tem algum valor em branco nas colunas presentes no parâmetro subset
rawdata.dropna(subset= ['pesid','data_inversa','dia_semana','horario','uf','br','km','municipio','causa_acidente','tipo_acidente','classificacao_acidente',
                       'fase_dia','sentido_via','condicao_metereologica','tipo_pista','tracado_via','uso_solo','id_veiculo','tipo_veiculo','marca',
                       'ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','sexo'], how = 'any', axis = 0, inplace = True)

print('Tamanho anterior do dataset em linhas: {} \nTotal de registros removidos: {}'.format(antes,(antes - rawdata.shape[0])))
print('Tamanho atual do dataset em linhas: {}'.format(rawdata.shape[0]))
# Out:
# Tamanho anterior do dataset em linhas: 3453255
# Total de registros removidos: 54924
# Tamanho atual do dataset em linhas: 3398331

# %%
#Verificando novamente os valores nulos/nan em cada coluna
rawdata.isnull().sum()
# Out:
# reg_id                          0
# id                              0
# pesid                           0
# data_inversa                    0
# dia_semana                      0
# horario                         0
# uf                              0
# br                              0
# km                              0
# municipio                       0
# causa_acidente                  0
# tipo_acidente                   0
# classificacao_acidente          0
# fase_dia                        0
# sentido_via                     0
# condicao_metereologica          0
# tipo_pista                      0
# tracado_via                     0
# uso_solo                        0
# id_veiculo                      0
# tipo_veiculo                    0
# marca                           0
# ano_fabricacao_veiculo          0
# tipo_envolvido                  0
# estado_fisico                   0
# idade                       45030
# sexo                            0
# ...

# %% [markdown]
# Beleza, eliminamos todos os registros em branco exceto a idade, embora o número de registros com a idade em branco tenha caído, não deletei estes registros pois existem algumas formas de preencher estes valores faltantes sem alterar as estatístcas da massa de dados. E os outros 6 campos restantes, serão populados mais tarde

# %% [markdown]
# #### Tratando os dados referentes às vítimas
# Durante o processo de tratamento do campo idade, reparei que todos os campos com informações referentes às vítimas precisavam de limpeza e tratamento...

# %%
#Consolidando os tipos de vítima
rawdata['tipo_envolvido'] = rawdata['tipo_envolvido'].str.rstrip()

# %%
#Verificando a contagem de registros para sexo
rawdata['sexo'].value_counts()
# Out:
# Masculino               2297239
# Feminino                 478765
# Masculino                245039
# M                        138503
# Inválido                 104197
# Feminino                  75738
# F                         39731
# Não Informado             12602
# Não Informado              3147
# I                          2707
# Ignorado                    663
# Name: sexo, dtype: int64

# %%
#Normalizando os registros p/ sexo
rawdata['sexo'] = rawdata['sexo'].str.rstrip()
rawdata['sexo'].replace(to_replace= {'M':'Masculino','F':'Feminino','I':'Não Informado','Inválido':'Não Informado','Ignorado':'Não Informado'}, inplace= True)
rawdata['sexo'].value_counts()
# Out:
# Masculino        2680781
# Feminino          594234
# Não Informado     123316
# Name: sexo, dtype: int64

# %%
#Verificando a contagem de registros para estado_fisico
rawdata['estado_fisico'].value_counts()
# Out:
# Ileso                   1914969
# Ferido Leve              575836
# Ferido Grave             228243
# Ileso                    166218
# Ignorado                 117300
# Lesões Leves             114071
# Ileso                     99904
# Morto                     63742
# Ferido Leve               55332
# Lesões Graves             31986
# Não Informado             11940
# Óbito                      9827
# Morto                      4551
# Ignorado                   4412
# Name: estado_fisico, dtype: int64

# %%
#Normalizando os registros p/ estado_fisico
rawdata['estado_fisico'] = rawdata['estado_fisico'].str.rstrip()

rawdata['estado_fisico'].replace(to_replace = {'Óbito':'Morto'}, inplace= True)

rawdata['estado_fisico'].value_counts()
# Out:
# Ileso            2181091
# Ferido Leve       631168
# Ferido Grave      228243
# Ignorado          121712
# Lesões Leves      114071
# Morto              78120
# Lesões Graves      31986
# Não Informado      11940
# Name: estado_fisico, dtype: int64

# %% [markdown]
# #### Tratando o campo idade
# Com as informações referente às vítimas organizadas, fica mais fácil a filtragem e tratamento do campo idade

# %%
#Observando estatísticas básicas sobre o atributo idade, com saída convertida em int
rawdata['idade'].describe().astype(int)
# Out:
# count    3353301
# mean          33
# std           29
# min           -1
# 25%           24
# 50%           33
# 75%           45
# max         2017
# Name: idade, dtype: int32

# %% [markdown]
# Observando as estatísticas básicas acima, fica claro que temos idades com problemas, poderia remover os registros problemáticos, ou ainda alterar seu valor para a média de 33 anos o que teria um menor impacto. Mas decidi fazer o segunte: Se for o registro de um condutor e a idade for <= 0, deleta-se o registro, já que bebês não dirigem fica claro ser um registro que não tem a consistência desejada

# %%
#Verificando registros que atendem ao filtro
rawdata[(rawdata['idade'] <= 0) & (rawdata['tipo_envolvido'] == 'Condutor')]
# Out:
#           reg_id       id      pesid data_inversa     dia_semana   horario  \
# 3         166203   408531  1178349.0   2008-07-20        Domingo  23:00:00
# 4         166204   408531  1178362.0   2008-07-20        Domingo  23:00:00
# 41        166241   408551  1197734.0   2008-02-08        Sábado   19:30:00
# 108       166308   408582  1177921.0   2008-07-31        Quinta   15:00:00
# 112       166312   408583  1177896.0   2008-07-26        Sábado   20:00:00
# 114       166314   408584  1177902.0   2008-07-28        Segunda  12:00:00
# 167       166367   408614  1178021.0   2008-03-08        Domingo  07:25:00
# 173       166373   408616  1177983.0   2008-03-08        Domingo  11:50:00
# 186       166386   408624  1178494.0   2008-03-08        Domingo  10:30:00
# 191       166391   408627  1178036.0   2008-07-28        Segunda  19:00:00
# 221           30   323828   909520.0   2008-01-01        Terça    04:30:00
# ...

# %%
#Armazenando os indexes das linhas que atendem ao filtro em uma mascara e dropando as linhas
f = rawdata[(rawdata['idade'] <= 0) & (rawdata['tipo_envolvido'] == 'Condutor')].index
rawdata.drop(f,axis=0, inplace= True)

# %%
#Verificando novamente as estatísticas básicas da massa de dados após a exclusão dos registros
rawdata['idade'].describe().astype(int)
# Out:
# count    3109586
# mean          35
# std           28
# min           -1
# 25%           26
# 50%           35
# 75%           46
# max         2017
# Name: idade, dtype: int32

# %%
#Verificando a quantidade de valores null
rawdata['idade'].isnull().value_counts()
# Out:
# False    3109586
# True       45030
# Name: idade, dtype: int64

# %%
#Verificando tipo de víima envolvida de acordo com a idade
rawdata[rawdata['idade'] <= 0]['tipo_envolvido'].value_counts()
# Out:
# Passageiro               143608
# Pedestre                  10579
# Cavaleiro                   150
# Proprietário de Carga         1
# Name: tipo_envolvido, dtype: int64

# %% [markdown]
# Após testes em uma cópia dos dados originais, levando em consideração que a idéia é deletar o menor número possível de registros com a idade em branco, e gerar o menor impacto nas métricas da massa de dados, adotei as seguintes medidas conforme bloco de comandos abaixo:

# %%
#Os valores null's do dataset, recebem como idade o valor da média das idades (mesmo valor da mediana no caso)
rawdata['idade'].fillna(value= 35, inplace= True)

#A variável f recebe o index ou posição de todos os registros em que a idade é maior do que 100
f = rawdata[rawdata['idade'] >= 100].index
#E em seguida, é utilizada como máscara para deletar todos os registros selecionados
rawdata.drop(f,axis = 0, inplace = True)

#Em seguida, todos os registros com a flag -1 no campo idade, tem a mesma substituída por um valor null
rawdata['idade'].replace(-1,np.nan, inplace= True)

# Que é interpolado visando redistribuir os mesmos no range de idade de forma o mais natural possível
rawdata['idade'].interpolate(inplace= True)

# %% [markdown]
# Realizado o tratamento do campo idade, posso verificar que outras colunas do dataset precisam de tratamento, começando com as variáveis categóricas, como fase_dia, traçado_pista, etc.

# %% [markdown]
# #### Tratando as outras colunas do dataset
# Depois de ter ajustado as que faziam referência às vítimas, segui este processo nos 2 blocos de comando abaixo para o restante do dataset. Onde apenas os 2 primeiros e os que necessitaram de atenção especial estão dispostos por mais de um bloco, e o restante por seguir o mesmo processo dos 2 blocos abaixo, foram 'abreviados' em função do comprimento do documento

# %%
#Verificando os valores para a coluna dia da semana
rawdata['dia_semana'].value_counts()
# Out:
# Sexta            432786
# Domingo          431020
# Sábado           410283
# Segunda          387817
# Quinta           357279
# Quarta           343523
# Terça            331701
# domingo           56837
# sábado            55792
# sexta-feira       51722
# segunda-feira     44864
# quinta-feira      43316
# quarta-feira      40681
# terça-feira       39632
# Sábado            30629
# Sexta             28551
# Quinta            23528
# Quarta            22194
# Terça             21220
# Name: dia_semana, dtype: int64

# %%
#Removendo os espaços à direita
rawdata['dia_semana'] = rawdata['dia_semana'].str.rstrip()

#Consolidando os registros de dia da semana
rawdata['dia_semana'].replace(to_replace = {'domingo':'Domingo','segunda-feira':'Segunda','terça-feira':'Terça','quarta-feira':'Quarta',
                                            'quinta-feira':'Quinta','sexta-feira':'Sexta','sábado':'Sábado'}, inplace= True)

#Checagem dos valores
rawdata['dia_semana'].value_counts()
# Out:
# Sexta      513059
# Sábado     496704
# Domingo    487857
# Segunda    432681
# Quinta     424123
# Quarta     406398
# Terça      392553
# Name: dia_semana, dtype: int64

# %%
#Verificando os valores para a coluna UF
#rawdata['uf'].value_counts()

#Verificando os registros que possuem (null) no valor de UF
rawdata.loc[rawdata.uf == '(null)']
# Out:
#           reg_id       id      pesid data_inversa dia_semana   horario  \
# 56141     132476   392093  1123381.0   2008-06-20      Sexta  17:40:00
# 56142     132477   392093  1123392.0   2008-06-20      Sexta  17:40:00
# 143056     93421   372626  1059884.0   2008-01-05     Quinta  18:00:00
# 161707     46009   348761   981634.0   2008-01-03     Sábado  01:30:00
# 161708     46010   348761   981645.0   2008-01-03     Sábado  01:30:00
# 161709     46011   348761   981681.0   2008-01-03     Sábado  01:30:00
# 161710     46012   348761   981689.0   2008-01-03     Sábado  01:30:00
# 161711     46013   348761   981697.0   2008-01-03     Sábado  01:30:00
# 1523625  1596817  1112105  3434053.0   2012-10-06    Domingo  19:11:00
# 1532846  1510623  1069183  3295929.0   2012-03-03     Sábado  19:45:00
# 1532847  1510624  1069183  3297560.0   2012-03-03     Sábado  19:45:00
# 1594949  1492234  1060316  3262992.0   2012-02-16     Quinta  07:14:00
# ...

# %% [markdown]
# Estes registros poderiam ser aproveitados, pois tem as informações do estado físico das vítimas, e o município onde ocorreu o acidente. Mas como são poucos registros e nenhum possui a informação referente a UF, BR (estrada) e KM do evento, serão descartados.

# %%
f = rawdata.loc[rawdata.uf == '(null)'].index
rawdata.drop(f, axis= 0, inplace = True)

# %%
#Verificando os valores para a coluna causa_acidente
#rawdata['causa_acidente'].value_counts()

#Substituindo a causa null pela causa 'Outras' já presente no dataset
rawdata['causa_acidente'].replace('(null)','Outras', inplace= True)

#Removendo os espaços à direita dos registros
rawdata['causa_acidente'] = rawdata['causa_acidente'].str.rstrip()

#Consolidando causas iguais
rawdata['causa_acidente'].replace(to_replace= {'Falta de atenção':'Falta de Atenção à Condução','Ingestão de álcool':'Ingestão de Álcool',
                                              'Defeito mecânico em veículo':'Defeito Mecânico no Veículo','Dormindo':'Condutor Dormindo',
                                               'Ultrapassagem indevida':'Ultrapassagem Indevida'}, inplace = True)
#Verificando alterações feitas
rawdata['causa_acidente'].value_counts()
# Out:
# Falta de Atenção à Condução                                                       1096709
# Outras                                                                             721525
# Não guardar distância de segurança                                                 333018
# Velocidade incompatível                                                            223261
# Ingestão de Álcool                                                                 140892
# Desobediência à sinalização                                                        134891
# Defeito Mecânico no Veículo                                                        120269
# Ultrapassagem Indevida                                                              93555
# Condutor Dormindo                                                                   80582
# Animais na Pista                                                                    62238
# ...

# %%
#Verficando os valores para a coluna tipo_acidente
#rawdata['tipo_acidente'].value_counts()

#Removendo os espaços à direita dos registros
rawdata['tipo_acidente'] = rawdata['tipo_acidente'].str.rstrip()

#Consolidando registros de mesmo tipo
rawdata['tipo_acidente'].replace(to_replace= {'Colisão Transversal':'Colisão transversal', 'Atropelamento de pessoa':'Atropelamento de Pedestre',
                                              'Atropelamento de animal':'Atropelamento de Animal', 'Derramamento de carga':'Derramamento de Carga',
                                              'Queda de motocicleta / bicicleta / veículo':'Queda de ocupante de veículo','Danos eventuais':'Danos Eventuais'}, inplace = True)
#Verificando as alterações realizadas
rawdata['tipo_acidente'].value_counts()
# Out:
# Colisão traseira                   1020507
# Colisão lateral                     540452
# Colisão transversal                 380193
# Saída de Pista                      309007
# Colisão frontal                     200902
# Capotamento                         129452
# Colisão com objeto fixo             111032
# Tombamento                           91586
# Atropelamento de Pedestre            86620
# Queda de ocupante de veículo         70809
# Atropelamento de Animal              50228
# Saída de leito carroçável            44970
# Colisão com bicicleta                27388
# Colisão com objeto móvel             23905
# Colisão com objeto estático          19068
# Danos Eventuais                      13300
# Incêndio                             11693
# Derramamento de Carga                10512
# Engavetamento                         9765
# Colisão com objeto em movimento       1970
# Name: tipo_acidente, dtype: int64

# %%
#Removendo espaços à direita dos registros da coluna classificação_acidente
rawdata['classificacao_acidente'] = rawdata['classificacao_acidente'].str.rstrip()

#Verificação dos registros que tem a classificação do acidente como (null)
#Utilização de opção de contexto do Pandas, para que o número maximo de colunas exibidas no dataset seja maior que o número de colunas do mesmo
with pd.option_context("display.max_columns", 40):
    display(rawdata.loc[rawdata['classificacao_acidente'] == '(null)'])

#Mais pra frente a classificação destes registros será corrigida - OK DONE
# Out:
#           reg_id     id      pesid data_inversa dia_semana   horario  uf   br  \
# 977939   1031445  26946  2715647.0   2011-04-16     Sábado  22:20:00  SP  153
# 2308848  2246470      8  5018708.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308849  2246471      8  5018708.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308850  2246472      8  5018711.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308851  2246473      8  5018711.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308854  2246476      9  5019034.0   2014-11-17    Segunda  20:50:00  BA  324
# 2308856  2246478     13  5018752.0   2014-11-20     Quinta  09:30:00  BA  367
# 2308857  2246479     14  5018864.0   2014-09-11    Domingo  22:50:00  SC  101
# 2308858  2246480     15  5018886.0   2014-11-19     Quarta  05:00:00  RJ  116
# 2308859  2246481     16  5018712.0   2014-11-22     Sábado  07:50:00  PR  277
# 2308860  2246482     17  5018903.0   2014-11-22     Sábado  06:10:00  SP  116
# ...

# %%
#Verificação dos regstros para a coluna fase_dia
#rawdata['fase_dia'].value_counts()

#Verificação dos registros com período do dia como (null). Como todos possuem os horários dos acidentes, podem ser corrigidos mais adiante
rawdata.loc[rawdata.fase_dia == '(null)'] #arruma dps - OK
# Out:
#           reg_id        id       pesid data_inversa dia_semana   horario  uf  \
# 93659     125779    388803   1112736.0   2008-12-06     Quinta  07:40:00  SC
# 102365    104026    377980   1077502.0   2008-05-14     Quarta  16:35:00  PA
# 102366    104027    377980   1077510.0   2008-05-14     Quarta  16:35:00  PA
# 155968    128572    390159   1116746.0   2008-06-15    Domingo  23:00:00  RJ
# 180045    144978    398215   1143569.0   2008-05-07     Sábado  10:40:00  GO
# 180046    144979    398215   1143598.0   2008-05-07     Sábado  10:40:00  GO
# 243675    193133    421933   1220890.0   2008-02-09      Terça  21:20:00  RJ
# 243676    193134    421933   1220893.0   2008-02-09      Terça  21:20:00  RJ
# 248306    344816    494955   1455392.0   2009-02-25     Quarta  16:40:00  MG
# 248307    344817    494955   1455402.0   2009-02-25     Quarta  16:40:00  MG
# 458397    524006    583668   1740000.0   2009-05-09     Sábado  21:15:00  CE
# ...

# %%
#Remoção dos espaços à direita dos registros
rawdata['fase_dia'] = rawdata['fase_dia'].str.rstrip()

#Consolidando registros de mesmo tipo
rawdata['fase_dia'].replace(to_replace= {'Plena Noite':'Plena noite'}, inplace = True)

rawdata['fase_dia'].value_counts()
# Out:
# Pleno dia      1871962
# Plena noite     932972
# Anoitecer       194030
# Amanhecer       154306
# (null)              89
# Name: fase_dia, dtype: int64

# %%
#Verificação dos regstros para a coluna sentido_via
#rawdata['sentido_via'].value_counts()

#Remoção dos espaços à direita dos registros
rawdata['sentido_via'] = rawdata['sentido_via'].str.rstrip()
#Verificação das alterações realizadas
rawdata['sentido_via'].value_counts()
# Out:
# Crescente      1625808
# Decrescente    1527551
# Name: sentido_via, dtype: int64

# %%
#Verificação dos regstros para a coluna condicao_meteorologica
#rawdata['condicao_metereologica'].value_counts()

#Remoção dos espaços à direita dos registros
rawdata['condicao_metereologica'] = rawdata['condicao_metereologica'].str.rstrip()

#Consolidação dos valores dos registros
rawdata['condicao_metereologica'].replace(to_replace= {'Céu Claro':'Ceu Claro','Ignorado':'Ignorada', 'Nevoeiro/neblina':'Nevoeiro/Neblina', '(null)':'Ignorada'}, inplace = True)

#Verificação das alterações realizadas
rawdata['condicao_metereologica'].value_counts()
# Out:
# Ceu Claro           1556502
# Nublado              570631
# Chuva                507512
# Sol                  414327
# Ignorada              52110
# Nevoeiro/Neblina      32132
# Garoa/Chuvisco        11484
# Vento                  7995
# Granizo                 468
# Neve                    198
# Name: condicao_metereologica, dtype: int64

# %%
#Verificação dos regstros para a coluna tipo_pista
#rawdata['tipo_pista'].value_counts()

#Verificação dos regstros para a coluna tipo_pista com o valor (null), que pode ser corrigido manualmente por serem poucos registros
rawdata[rawdata.tipo_pista == '(null)'] #arruma dps
# Out:
#           reg_id        id      pesid data_inversa dia_semana   horario  uf  \
# 1057829  1086726    858063  2617891.0   2011-02-17     Quinta  03:30:00  MG
# 1143906  1114698    871779  2662718.0   2011-12-03     Sábado  04:20:00  CE
# 1438673  1335773    984377  3017467.0   2011-01-10     Sábado  14:30:00  GO
# 1491073  1504702   1066266  3283152.0   2012-02-23     Quinta  11:00:00  MG
# 1588674  1516963   1072411  3303061.0   2012-10-03     Sábado  03:30:00  RS
# 2406663  2286089  83143014  4560648.0   2014-03-02    Segunda  17:20:00  PA
# 2406664  2286090  83143014  4560664.0   2014-03-02    Segunda  17:20:00  PA
# 2451805  2571023  83280429  5023074.0   2014-11-24    Segunda  12:10:00  MG
# 2578439  2568215  83278982  5018698.0   2014-11-19     Quarta  09:20:00  RJ
# 2578440  2568216  83278982  5018701.0   2014-11-19     Quarta  09:20:00  RJ
# 2696704  2683493  83332560  5205067.0   2015-03-23    Segunda  19:30:00  MT
# ...

# %%
#Remoção dos espaços à direita dos registros
rawdata['tipo_pista'] = rawdata['tipo_pista'].str.rstrip()
#Verificação das alterações realizadas
rawdata['tipo_pista'].value_counts()
# Out:
# Simples     1696825
# Dupla       1220604
# Múltipla     235918
# (null)           12
# Name: tipo_pista, dtype: int64

# %%
#Verificação dos regstros para a coluna tracado_via
#rawdata['tracado_via'].value_counts()

#Remoção dos registros onde o traçado da via tem (null) como valor
f = rawdata[rawdata.tracado_via == '(null)'].index
rawdata.drop(f, axis = 0, inplace = True) # Os registros com valor '(null)' na coluna tipo_pista também tinham a coluna tracado_via com valores null, e foram deletados

#Remoção dos espaços à direita dos registros
rawdata['tracado_via'] = rawdata['tracado_via'].str.rstrip()

#Verificação das alterações realizadas
rawdata['tracado_via'].value_counts()
# Out:
# Reta                     2286055
# Curva                     599797
# Cruzamento                193350
# Não Informado              33723
# Interseção de vias         15987
# Desvio Temporário           9672
# Rotatória                   6380
# Retorno Regulamentado       3815
# Viaduto                     2350
# Ponte                       1920
# Túnel                        298
# Name: tracado_via, dtype: int64

# %%
#Verificação dos regstros para a coluna uso_solo
#rawdata['uso_solo'].value_counts()

#Remoção dos espaços à direita dos registros
rawdata['uso_solo'] = rawdata['uso_solo'].str.rstrip()

#Consolidação dos registros
rawdata['uso_solo'].replace(to_replace= {'Sim':'Urbano','Não':'Rural'}, inplace = True)

#Verificação das alterações realizadas
rawdata['uso_solo'].value_counts()
# Out:
# Urbano    1639781
# Rural     1513566
# Name: uso_solo, dtype: int64

# %%
#Remoção dos espaços à direita dos registros
rawdata['tipo_veiculo'] = rawdata['tipo_veiculo'].str.rstrip()

#Consolidação dos registros
rawdata['tipo_veiculo'].replace(to_replace= {'Motocicletas':'Motocicleta','Micro-ônibus':'Microônibus','Semi-Reboque':'Semireboque','(null)':'Desconhecido'}, inplace = True)

#Verificação das alterações realizadas
rawdata['tipo_veiculo'].value_counts()
# Out:
# Automóvel             1564107
# Motocicleta            337648
# Caminhão               294943
# Caminhão-Trator        285029
# Caminhonete            243986
# Ônibus                 132073
# Camioneta              104979
# Desconhecido            42449
# Motoneta                35099
# Microônibus             32483
# Caminhão-trator         28475
# Utilitário              21241
# Bicicleta               18932
# Ciclomotor               4649
# Semireboque              1616
# Trator de rodas          1381
# Carroça                  1125
# Não identificado          986
# Caminhão-Tanque           975
# Reboque                   342
# Triciclo                  251
# Charrete                  163
# Bonde / Trem              147
# Trator misto              117
# Trator de esteiras         44
# Carro-de-mao               43
# Não Informado              22
# Outros                     20
# Motor-Casa                 11
# Quadriciclo                10
# Trem-bonde                  1
# ...

# %%
#Remoção dos espaços à direita dos registros
rawdata['marca'] = rawdata['marca'].str.rstrip()

#Consolidação dos registros
rawdata['marca'].replace(to_replace= {'I':'Importado-Desconhecido','(null)':'Desconhecido'}, inplace = True)

# %% [markdown]
# #### Acertando os detalhes
# Em algumas colunas existem registros com o valor '(null)' que marquei para correção manual. Correções estas que vão de classificação de registros, a input de dados levantados manualmente de acordo com pesquisas naquele site (Aquele um das buscas)

# %% [markdown]
# ##### Classificação do Acidente
# Temos 20 registros que não foram classificados de acordo com o estado das vítimas, embora os registros tragam a informação referente ao estado das vítimas. Basta então identificar estes 20 registros, buscar a informação no campo estado_vitima e estabelecer a regra de relacionamento de acordo com os outros registros

# %%
with pd.option_context('max_columns',45):
    display(rawdata.loc[rawdata['classificacao_acidente'] == '(null)'])
# Out:
#           reg_id     id      pesid data_inversa dia_semana   horario  uf   br  \
# 977939   1031445  26946  2715647.0   2011-04-16     Sábado  22:20:00  SP  153
# 2308848  2246470      8  5018708.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308849  2246471      8  5018708.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308850  2246472      8  5018711.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308851  2246473      8  5018711.0   2014-11-22     Sábado  09:35:00  PR  376
# 2308854  2246476      9  5019034.0   2014-11-17    Segunda  20:50:00  BA  324
# 2308856  2246478     13  5018752.0   2014-11-20     Quinta  09:30:00  BA  367
# 2308857  2246479     14  5018864.0   2014-09-11    Domingo  22:50:00  SC  101
# 2308858  2246480     15  5018886.0   2014-11-19     Quarta  05:00:00  RJ  116
# 2308859  2246481     16  5018712.0   2014-11-22     Sábado  07:50:00  PR  277
# 2308860  2246482     17  5018903.0   2014-11-22     Sábado  06:10:00  SP  116
# ...

# %%
with pd.option_context('max_columns',45):
    display(rawdata.loc[rawdata['classificacao_acidente'] == 'Ignorado'].head())
# Out:
#       reg_id      id      pesid data_inversa dia_semana   horario  uf   br  \
# 2564   28287  339283   952625.0   2008-02-02     Sábado  18:40:00  DF   70
# 2565   28288  339283   952643.0   2008-02-02     Sábado  18:40:00  DF   70
# 4035  121016  386451  1112343.0   2008-05-06     Quinta  20:20:00  BA  324
# 8362   97873  374932  1067264.0   2008-05-05    Segunda  20:25:00  DF   60
# 8373   97884  374939  1067516.0   2008-01-05     Quinta  16:05:00  DF   70
#
#          km         municipio causa_acidente    tipo_acidente  \
# 2564    8.8          BRASILIA         Outras  Colisão lateral
# 2565    8.8          BRASILIA         Outras  Colisão lateral
# 4035  530.8  FEIRA DE SANTANA         Outras   Saída de Pista
# 8362   19.9          BRASILIA         Outras      Capotamento
# 8373   18.2          BRASILIA         Outras      Capotamento
#
#      classificacao_acidente     fase_dia  sentido_via condicao_metereologica  \
# ...

# %% [markdown]
# Os registros com classificação 'Ignorado', por não possuírem informações sobre o estado físico das vítimas serão deletados.
# Mas, para o funcionamento desejado do método .iloc() que será utilizado, é necessária a reindexação do dataset, conforme explicado no artigo : https://www.linkedin.com/pulse/transito-brasil-o-que-mudou-em-10-anos-parte-3-ramon-nogueira/

# %%
f = rawdata.loc[rawdata['classificacao_acidente'] == 'Ignorado'].index
rawdata.drop(f, axis= 0, inplace= True)

# %%
#Resetando o index do dataset
rawdata.reset_index(inplace= True)

# %%
#R recebe os indexes onde o campo classificacao_acidente tem o valor '(null)'
R = rawdata.loc[rawdata['classificacao_acidente'] == '(null)'].index

# %%
#Loop que percorre os indexes de R e preenche a classificacão do acidente de acordo com o estado da vítima
for item in R:
    #print('valor de item: ', item)
    #display(rawdata.iloc[[item]])
    if (rawdata.iloc[[item],[25]].values == 'Ileso'):
        rawdata.iloc[item,13] = 'Sem Vítimas'
        print('Classificação Acidente Atualizada')
            
    elif (rawdata.iloc[[item],[25]].values == 'Ferido Leve'):
        rawdata.iloc[item,13] = 'Com Vítimas Feridas'
        print('Classificação Acidente Atualizada HUE')
            
    elif (rawdata.iloc[[item],[25]].values == 'Morto'):
        rawdata.iloc[item,13] = 'Com Vítimas Fatais'
        print('Classificação Acidente Atualizada R.I.P')
        
    else:
        print('oh noooeZ')
# Out:
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada HUE
# Classificação Acidente Atualizada HUE
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada HUE
# Classificação Acidente Atualizada HUE
# Classificação Acidente Atualizada HUE
# oh noooeZ
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada R.I.P
# Classificação Acidente Atualizada
# Classificação Acidente Atualizada
# oh noooeZ
# Classificação Acidente Atualizada
# oh noooeZ

# %%
#Verificação dos 3 registros que continuaram como null
with pd.option_context('max_columns',45):
    display(rawdata.loc[rawdata['classificacao_acidente'] == '(null)'])
# Out:
#            index   reg_id    id      pesid data_inversa dia_semana   horario  \
# 2119014  2308862  2246484    17  5018910.0   2014-11-22     Sábado  06:10:00
# 2119019  2308867  2246489   332  5018917.0   2014-11-22     Sábado  10:20:00
# 2119021  2308869  2246491  1175  5019295.0   2014-11-22     Sábado  19:20:00
#
#          uf   br     km       municipio               causa_acidente  \
# 2119014  SP  116    550  BARRA DO TURVO  Falta de Atenção à Condução
# 2119019  ES  101    146        LINHARES  Desobediência à sinalização
# 2119021  BA  116  778.1        PLANALTO           Ingestão de Álcool
#
#                      tipo_acidente classificacao_acidente     fase_dia  \
# 2119014           Colisão traseira                 (null)    Amanhecer
# 2119019        Colisão transversal                 (null)    Pleno dia
# 2119021  Atropelamento de Pedestre                 (null)  Plena noite
#
#          sentido_via condicao_metereologica tipo_pista tracado_via uso_solo  \
# ...

# %%
#Update manual dos valores para os 3 registros acima
rawdata.iloc[2119014,13] = 'Com Vítimas Feridas'
rawdata.iloc[2119019,13] = 'Com Vítimas Feridas'
rawdata.iloc[2119021,13] = 'Com Vítimas Fatais'

# %%
#Verificação dos indexes de R com os valores corrigidos
rawdata.iloc[R,13]
# Out:
# 907731             Sem Vítimas
# 2119003            Sem Vítimas
# 2119004            Sem Vítimas
# 2119005            Sem Vítimas
# 2119006            Sem Vítimas
# 2119007            Sem Vítimas
# 2119008    Com Vítimas Feridas
# 2119009    Com Vítimas Feridas
# 2119010            Sem Vítimas
# 2119011    Com Vítimas Feridas
# 2119012    Com Vítimas Feridas
# 2119013    Com Vítimas Feridas
# 2119014    Com Vítimas Feridas
# 2119015            Sem Vítimas
# 2119016     Com Vítimas Fatais
# 2119017            Sem Vítimas
# 2119018            Sem Vítimas
# 2119019    Com Vítimas Feridas
# 2119020            Sem Vítimas
# 2119021     Com Vítimas Fatais
# Name: classificacao_acidente, dtype: object

# %%
rawdata['classificacao_acidente'].value_counts()
# Out:
# Sem Vítimas            1545430
# Com Vítimas Feridas    1407130
# Com Vítimas Fatais      197128
# Name: classificacao_acidente, dtype: int64

# %% [markdown]
# ### Tratamento de horários e coluna fase_dia
# Durante o desenrolar dos tratamentos, me dei conta de que seria necessário passar um 'pente fino' nos valores de horário x fase do dia, além de ter que levam em conta o horário de verão de 2008 até 2018

# %%
#Verificação de consistência dos dados
rawdata.loc[(rawdata.fase_dia == 'Pleno dia'),'horario'].value_counts()
# Out:
# 16:00:00    43925
# 15:00:00    41285
# 16:30:00    38892
# 17:00:00    37903
# 15:30:00    37340
# 14:00:00    35738
# 08:00:00    34826
# 14:30:00    33349
# 09:00:00    33260
# 10:00:00    33192
# 11:00:00    32635
# 08:30:00    31357
# 07:30:00    31211
# 09:30:00    30271
# 10:30:00    29593
# 11:30:00    29069
# 13:00:00    28974
# 13:30:00    28418
# 12:00:00    28327
# 17:30:00    26273
# 12:30:00    25203
# 07:00:00    24085
# 16:20:00    18367
# 16:40:00    18102
# 07:50:00    17522
# 07:40:00    17501
# 15:40:00    16931
# 15:20:00    16344
# 14:20:00    15646
# 14:40:00    15252
#             ...
# 05:17:00        1
# 00:03:00        1
# 21:17:00        1
# 22:41:00        1
# 00:22:00        1
# 06:50:47        1
# 01:41:00        1
# 20:52:00        1
# 23:57:00        1
# 03:32:00        1
# 01:51:00        1
# 23:36:00        1
# 23:02:00        1
# 23:29:00        1
# 15:20:18        1
# 05:39:00        1
# 05:52:00        1
# 05:31:00        1
# 22:54:00        1
# ...

# %% [markdown]
# Após identificar inconsistências, como horário 22:54 classificado como Pleno Dia, e em conjunto com os valores '(null)', decidi modificar o dataset, de modo a aproveitar o tipo datetime da coluna 'data_inversa', concatenando também o horário. Como não poderia simplesmente adicionar o horário às informações de data já existentes, passei a coluna 'data_inversa' como string, concatenando o horário, guardando numa nova coluna e tipando a mesma como datetime, mantendo a consistência das informações de data/hora.

# %%
#Realizando a concatenação de data_inversa como string com a coluna horário, também string e tipando a nova coluna como datetime
rawdata['data_hora'] = rawdata['data_inversa'].astype(str) + ' ' + rawdata['horario']
rawdata['data_hora'] = pd.to_datetime(rawdata['data_hora'])

#Reordenando as colunas do dataset
rawdata = rawdata[['index', 'reg_id', 'id', 'pesid', 'data_inversa', 'data_hora', 'dia_semana',
       'horario', 'uf', 'br', 'km', 'municipio', 'causa_acidente',
       'tipo_acidente', 'classificacao_acidente', 'fase_dia', 'sentido_via',
       'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
       'id_veiculo', 'tipo_veiculo', 'marca', 'ano_fabricacao_veiculo',
       'tipo_envolvido', 'estado_fisico', 'idade', 'sexo', 'ilesos',
       'feridos_leves', 'feridos_graves', 'mortos', 'latitude', 'longitude']]

#Drop das colunas utilizadas já que tornaram-se informações redundantes
rawdata.drop(labels= ['data_inversa'], axis= 1, inplace= True)

# %% [markdown]
# Todos os registros de fase_dia estão completamente inúteis, conforme verificado com os comandos comentados abaixo

# %%
#rawdata.loc[(rawdata.fase_dia == 'Pleno dia'), 'data_hora'].dt.hour.value_counts()
#rawdata.loc[(rawdata.fase_dia == 'Plena noite'), 'data_hora'].dt.hour.value_counts()
#rawdata.loc[(rawdata.fase_dia == 'Anoitecer'), 'data_hora'].dt.hour.value_counts()
#rawdata.loc[(rawdata.fase_dia == 'Amanhecer'), 'data_hora'].dt.hour.value_counts()

# %% [markdown]
# A intenção original era utilizar a coluna data_hora e definir a fase do dia levando em consideração o horário de brasília e o horário de verão. Mas após refletir me ocorreu que seria muito mas simples e fácil utilizar as própias features do dataset, utilizando os valores 'Amanhecer' e 'Anoitecer' como uma espécie de buffer, diminuíndo a importancia da aplicação do horário de verão. E durante pesquisa, notei que se a questão do fuso-horário fosse tão importante assim, eu teria que implementar os 4 fusos utilizados no Brasil, e aplicar o horário de verão para cada estado que participa do mesmo, visto que não são todos que aderem ao horário de verão.
#
# Keep It Simple, Stupid.

# %% [markdown]
# Tendo em mente que utilizaria os valores já existentes do dataset, escrevi as seguintes condições:
#
#     Amanhecer das 5am as 6:59am
#     Pleno dia das 7am as 5:59pm
#     Anoitecer das 6pm as 7:59pm
#     Plena noite das 8pm as 4:59am

# %%
#
#from datetime import datetime
#x5 = datetime.strptime('05:00:00','%H:%M:%S') #Amanhecer
#x6 = datetime.strptime('06:59:00','%H:%M:%S') #Amanhecer
#x7 = datetime.strptime('07:00:00','%H:%M:%S') #Pleno dia
#x17 = datetime.strptime('17:59:00','%H:%M:%S') #Pleno dia
#x18 = datetime.strptime('18:00:00','%H:%M:%S') #Anoitecer
#x19 = datetime.strptime('19:59:00','%H:%M:%S') #Anoitecer
#x20 = datetime.strptime('20:00:00','%H:%M:%S') #Plena noite
#x4 = datetime.strptime('04:59:00','%H:%M:%S') #Plena noite
#

# %%
#
#i = 0
#for i in rawdata.iterrows():
#
#    if (rawdata.data_hora[i].time() >= x5.time() and rawdata.data_hora[i].time() <= x6.time()):
#        rawdata.fase_dia[i] = 'Amanhecer'
#        #print('Amanhecer')
#        #print('De horario is: ',rawdata.data_hora[i].time())
#    elif (rawdata.data_hora[i].time() >= x7.time() and rawdata.data_hora[i].time() <= x17.time()):
#        rawdata.fase_dia[i] = 'Pleno dia'
#        #print('PReno dia')
#        #print('De horario is: ',rawdata.data_hora[i].time())
#    elif (rawdata.data_hora[i].time() >= x18.time() and rawdata.data_hora[i].time() <= x19.time()):
#        rawdata.fase_dia[i] = 'Anoitecer'
#        #print('Anoitecer')
#        #print('De horario is: ',rawdata.data_hora.dt.time[i])
#    elif (rawdata.data_hora[i].time() >= x20.time() and rawdata.data_hora[i].time() <= x4.time()):
#        rawdata.fase_dia[i] = 'Plena noite'
#       #print('PRena Noche')
#        #print('De horario is: ',rawdata.data_hora[i].time())
#

# %% [markdown]
# Escrevi o código comentado acima, que funciona, mas a performance do mesmo é horrível, por estar fazendo operações com tempo, por utilizar o método iterrows() que não é o mais indicado e por conta do tamanho do dataset. Rodar este bloco de comando todas as vezes que abrisse o notebook iria consumir muito tempo.
#
# Por conta disso, decidi jogar a toalha e simplesmente dropar a coluna fase_dia, apesar de ter o código escrito.

# %%
rawdata.drop(labels='fase_dia', axis = 1, inplace = True)

# %% [markdown]
# Durante o processo de acerto dos tipos das colunas, me deparei com outra inconsistência que me forçou a tomar uma decisão: Todos os registros que eu havia marcado como veículo 'desconhecido', tinham os anos de fabricação dos veículos como '(null)', e além disso haviam alguns registros com anos completamente errados

# %%
#Exibindo 1 registro em tela e as informações do dataset
with pd.option_context('max_columns',45):
    display(rawdata.head(1))

print(rawdata.info())
# Out:
#    index  reg_id      id      pesid           data_hora dia_semana   horario  \
# 0      0  166200  408530  1177694.0 2008-07-30 14:30:00     Quarta  14:30:00
#
#    uf   br     km municipio               causa_acidente        tipo_acidente  \
# 0  SC  101  322.2    LAGUNA  Falta de Atenção à Condução  Colisão transversal
#
#   classificacao_acidente  sentido_via condicao_metereologica tipo_pista  \
# 0    Com Vítimas Feridas  Decrescente                    Sol      Dupla
#
#   tracado_via uso_solo id_veiculo tipo_veiculo                marca  \
# 0        Reta   Urbano     726571    Automóvel  FORD/ESCORT 1.6I GL
#
#   ano_fabricacao_veiculo tipo_envolvido estado_fisico  idade       sexo  \
# 0                   1995     Passageiro   Ferido Leve   10.0  Masculino
#
#    ilesos  feridos_leves  feridos_graves  mortos  latitude  longitude
# 0     NaN            NaN             NaN     NaN       NaN        NaN
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
#Acertando os tipos de algumas colunas
#A primeira vez que executei este bloco, tive uma mensagem de erro, informando que era impossível a conversão de '(null)' em int
rawdata['pesid'] = rawdata['pesid'].astype(object)
rawdata['br'] = rawdata['br'].astype(int)
rawdata['km'].replace(',','.', inplace= True)
#rawdata['ano_fabricacao_veiculo'] = rawdata['ano_fabricacao_veiculo'].astype(int)
rawdata['idade'] = rawdata['idade'].astype(int)

# %%
# Comecei a investgar mais a fundo a coluna ano_fab_veiculo
with pd.option_context('max_columns',45):
    display(rawdata.loc[rawdata['ano_fabricacao_veiculo'] == '(null)'])
# Out:
#            index   reg_id        id        pesid           data_hora  \
# 38            40   166240    408551   1.1973e+06 2008-02-08 19:30:00
# 138          144   166344    408600  1.17797e+06 2008-03-08 09:00:00
# 189          199        8    323811       904276 2008-01-01 01:40:00
# 213          224       33    323830       904402 2008-01-01 01:00:00
# 214          225       34    323831       908483 2008-01-01 03:10:00
# 237          248       57    323853       904408 2008-01-01 03:30:00
# 257          270       79    323902       904572 2008-01-01 07:45:00
# 275          288       97    323915       904607 2008-01-01 09:00:00
# 371          386      195    323994       914454 2008-01-01 10:20:00
# 417          433      242    324024       904957 2008-01-01 17:25:00
# 455          473      282    324049       905041 2008-01-01 06:30:00
# 575          601      410    324153       905501 2008-01-01 23:00:00
# 576          602      411    324153       905502 2008-01-01 23:00:00
# ...

# %%
#E aqui peguei mais inconsistências
rawdata['ano_fabricacao_veiculo'].value_counts()
# Out:
# 2008      274843
# 2010      237314
# 2007      221250
# 2009      219742
# 2011      212472
# 2006      161072
# 2012      145450
# 2005      140415
# 2013      137289
# 2004      127352
# 2003       97407
# 2001       94155
# 2014       93442
# 2002       90501
# 2000       81241
# 1997       76730
# 1998       66547
# 1999       61847
# 1996       58814
# 1995       57453
#            55256
# 2015       48576
# 1994       43726
# (null)     42340
# 1993       31982
# 2016       23784
# 1991       22576
# 1990       20553
# 1992       20368
# 1989       19943
#            ...
# 1885           2
# 1955           2
# 2201           2
# 1917           1
# 1899           1
# 1879           1
# 9181           1
# 1852           1
# 2101           1
# 1928           1
# 1896           1
# 1939           1
# 5007           1
# 2087           1
# 5010           1
# 2112           1
# 1936           1
# 2205           1
# 1894           1
# 1945           1
# 2998           1
# ...

# %% [markdown]
# Por conta destas inconsistências, decidi salvar uma cópia do dataset e tratar a cópia dos dados, mas chegou um certo ponto em que me perdi no que havia sido tratado em qual lugar e decidi voltar e continuar alterando o dataset original, mesmo que significasse perder mais alguns registros (que a essa altura do campeonato eu já estava se saco cheio de tentar evitar apagar mais registros)

# %% [markdown]
# Em preparação para a contagem das vítimas, os dados de ano de fabricação do veículo precisam estar íntegros, pois a coluna será utilizada como uma das features para treinamento do modelo que irá classificar as vítimas

# %%
rawdata['ano_fabricacao_veiculo'].unique()
# Out:
# array(['1995', '2006', '2007', '1990', '1991', '2003', '1999', '1987',
#        '1993', '1984', '1996', '2001', '2000', '2008', '(null)', '1986',
#        '1997', '2005', '1994', '    ', '1988', '1992', '2002', '1998',
#        '2004', '1977', '1985', '1975', '1981', '1983', '1966', '1978',
#        '1989', '1982', '1979', '1980', '1969', '1976', '1967', '1971',
#        '1968', '1946', '1970', '1972', '1974', '1965', '1973', '1964',
#        '1962', '1960', '1963', '1958', '1959', '1900', '1961', '2009',
#        '1957', '1952', '1936', '9999', '2207', '1857', '2201', '2199',
#        '1951', '2208', '2010', '1942', '1953', '1948', '1901', '2087',
#        '8888', '1955', '2088', '2012', '1956', '2209', '1939', '1851',
#        '1954', '2011', '2222', '2013', '2014', '1894', '2066', '1950',
#        '2070', '2099', '1947', '1928', '2101', '1929', '4112', '2015',
#        '2016', '5007', '1899', '5010', '3004', '2202', '1896', '2975',
# ...

# %%
f = rawdata.loc[rawdata['ano_fabricacao_veiculo'] == '(null)'].index
rawdata.drop(f, axis= 0, inplace= True)

f = rawdata.loc[rawdata['ano_fabricacao_veiculo'] == '    '].index
rawdata.drop(f, axis= 0, inplace= True)

# %%
rawdata['ano_fabricacao_veiculo'] = rawdata['ano_fabricacao_veiculo'].astype(int)

# %%
#Deletando os registros com ano de fabricação do veículo menores que 1917
f = rawdata[rawdata.ano_fabricacao_veiculo <= 1917].index
rawdata.drop(f, axis= 0, inplace = True)

#E deletando os registros com ano fabricação do veícuo acima de 2018
f = rawdata[rawdata.ano_fabricacao_veiculo > 2018].index
rawdata.drop(f, axis= 0, inplace = True)

# %%
#Verficando as estatísticas basicas da coluna 'ano_fabricacao_veiculo'
rawdata['ano_fabricacao_veiculo'].describe().astype(int)
# Out:
# count    3051850
# mean        2004
# std            7
# min         1928
# 25%         2001
# 50%         2007
# 75%         2010
# max         2018
# Name: ano_fabricacao_veiculo, dtype: int32

# %%
rawdata['km'] = rawdata['km'].str.replace(',','.')
rawdata['km'] = rawdata['km'].astype(float)

# %%
rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3051850 entries, 0 to 3149687
# Data columns (total 33 columns):
# index                     int64
# reg_id                    int64
# id                        object
# pesid                     object
# data_hora                 datetime64[ns]
# dia_semana                object
# horario                   object
# uf                        object
# br                        int32
# km                        float64
# municipio                 object
# causa_acidente            object
# tipo_acidente             object
# classificacao_acidente    object
# sentido_via               object
# condicao_metereologica    object
# tipo_pista                object
# tracado_via               object
# uso_solo                  object
# id_veiculo                object
# tipo_veiculo              object
# marca                     object
# ano_fabricacao_veiculo    int32
# tipo_envolvido            object
# estado_fisico             object
# ...

# %% [markdown]
# ### Contagem das Vitimas
# Com os registros devidamente tratados, percebi que havia deixado passar um detalhe relativamente importante, principalmente no meu caso que não desejo deletar registros a toa.
# Os valores 'Ignorado' e 'Não Informado' não podem ser utilizados para contagem de vítimas. No total são 133,652 registros, que representam cerca de 4,2% do volume total de dados.
#
# Para corrigir isto, preciso investigar e identificar as correlações entre as features para criar um modelo para reclassificação destes registros.

# %%
#Import do módulo preprocessing e escolha das features para um novo dataset chamado 'fset'
from sklearn import preprocessing

fset = rawdata[['br','km','causa_acidente','tipo_acidente','classificacao_acidente',
               'condicao_metereologica','tipo_pista','tracado_via','tipo_veiculo','marca',
               'ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo']].copy()

fset.head()
# Out:
#     br     km               causa_acidente            tipo_acidente  \
# 0  101  322.2  Falta de Atenção à Condução      Colisão transversal
# 1  101  322.2  Falta de Atenção à Condução      Colisão transversal
# 2  101  322.2  Falta de Atenção à Condução      Colisão transversal
# 3  101  215.5                       Outras           Saída de Pista
# 4   40  123.0                       Outras  Colisão com objeto fixo
#
#   classificacao_acidente condicao_metereologica tipo_pista tracado_via  \
# 0    Com Vítimas Feridas                    Sol      Dupla        Reta
# 1    Com Vítimas Feridas                    Sol      Dupla        Reta
# 2    Com Vítimas Feridas                    Sol      Dupla        Reta
# 3    Com Vítimas Feridas                  Chuva    Simples       Curva
# 4            Sem Vítimas              Ceu Claro   Múltipla        Reta
#
#   tipo_veiculo                marca  ano_fabricacao_veiculo tipo_envolvido  \
# ...

# %% [markdown]
# O entuito é prever valores para substituir 'Não informado' e 'Ignorado', logo estes valores não podem fazer parte dos valores que o modelo terá de apreender, e dever ser removidos do dataset com as features selecionadas

# %%
f = fset.loc[fset['estado_fisico'] == 'Não Informado'].index
fset.drop(f, axis= 0, inplace = True)

f = fset.loc[fset['estado_fisico'] == 'Ignorado'].index
fset.drop(f, axis= 0, inplace = True)

# %%
#Alocando as variaveis preditoras ou features
X = fset[['br','km','causa_acidente','tipo_acidente','classificacao_acidente',
               'condicao_metereologica','tipo_pista','tracado_via','tipo_veiculo','marca',
               'ano_fabricacao_veiculo','tipo_envolvido','idade','sexo']].values

#Alocando a variável target
y = fset['estado_fisico'].values

# %% [markdown]
# Depois de montados os vetores, precisava transformar todas as informações não numéricas, em informações numéricas. Pra isso foi utilizada a função LabelEncoder do módulo preprocessing da biblioteca scikit-learn.
#
# A nomenclatura das variáveis seguiu um padrão, com o prefixo 'Le_' de Label Encoder.
# No exemplo abaixo, o método .fit() recebe uma lista com os valores presentes em X. Eu vacilei e escrevi um por um, mas nas outras conversões utilizei a função .unique(), que traz todos os valores únicos na coluna do dataset

# %%
Le_causa = preprocessing.LabelEncoder()
Le_causa.fit(['Falta de Atenção à Condução','Outras','Não guardar distância de segurança','Velocidade incompatível','Ingestão de Álcool','Desobediência à sinalização',
             'Defeito Mecânico no Veículo','Ultrapassagem Indevida','Condutor Dormindo','Animais na Pista','Defeito na via','Velocidade Incompatível',
             'Desobediência às normas de trânsito pelo condutor','Pista Escorregadia','Falta de Atenção do Pedestre','Avarias e/ou desgaste excessivo no pneu',
             'Defeito na Via','Restrição de Visibilidade','Mal Súbito','Objeto estático sobre o leito carroçável','Sinalização da via insuficiente ou inadequada',
             'Carga excessiva e/ou mal acondicionada','Fenômenos da Natureza','Deficiência ou não Acionamento do Sistema de Iluminação/Sinalização do Veículo',
             'Agressão Externa','Ingestão de álcool e/ou substâncias psicoativas pelo pedestre','Desobediência às normas de trânsito pelo pedestre','Ingestão de Substâncias Psicoativas'])
X[:,2] = Le_causa.transform(X[:,2])

# %%
Le_tipo_acidente = preprocessing.LabelEncoder()
Le_tipo_acidente.fit(fset.tipo_acidente.unique())
X[:,3] = Le_tipo_acidente.transform(X[:,3])

# %%
Le_class_acidente = preprocessing.LabelEncoder()
Le_class_acidente.fit(fset.classificacao_acidente.unique())
X[:,4] = Le_class_acidente.transform(X[:,4])

# %%
Le_clima = preprocessing.LabelEncoder()
Le_clima.fit(fset.condicao_metereologica.unique())
X[:,5] = Le_clima.transform(X[:,5])

# %%
Le_pista = preprocessing.LabelEncoder()
Le_pista.fit(fset.tipo_pista.unique())
X[:,6] = Le_pista.transform(X[:,6])

# %%
Le_tracado = preprocessing.LabelEncoder()
Le_tracado.fit(fset.tracado_via.unique())
X[:,7] = Le_tracado.transform(X[:,7])

# %%
Le_veiculo = preprocessing.LabelEncoder()
Le_veiculo.fit(fset.tipo_veiculo.unique())
X[:,8] = Le_veiculo.transform(X[:,8])

# %%
Le_marca = preprocessing.LabelEncoder()
Le_marca.fit(fset.marca.unique())
X[:,9] = Le_marca.transform(X[:,9])

# %%
Le_envolvido = preprocessing.LabelEncoder()
Le_envolvido.fit(fset.tipo_envolvido.unique())
X[:,11] = Le_envolvido.transform(X[:,11])

# %%
Le_sexo = preprocessing.LabelEncoder()
Le_sexo.fit(fset.sexo.unique())
X[:,13] = Le_sexo.transform(X[:,13])

# %% [markdown]
# Após ter convertido os valores do array X, é preciso normalizar os valores, para uma melhor performance do algoritmo de classificação usado, que no caso é o SGDClassifier

# %%
std = preprocessing.StandardScaler()
std.fit(X)
Xstd = std.transform(X)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# D:\Programas\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
print ('Média antes da normalização: {:.2f}'.format(X.mean()),'\nDesvio padrão antes da normalização: {:.2f}'.format(X.std()))
print('')
print ('Média depois da normalização: {:.2f}'.format(Xstd.mean()),'\nDesvio padrão depois da normalização: {:.2f}'.format(Xstd.std()))
# Out:
# Média antes da normalização: 572.23
# Desvio padrão antes da normalização: 1857.15
#
# Média depois da normalização: 0.00
# Desvio padrão depois da normalização: 1.00

# %% [markdown]
# Depois de normalizado, o array Xstd que contém os valores das features que julguei importante para uma predição, precisa ser dividido em 4 partes:
# - X_train: Uma de treino do modelo, onde o algoritmo irá 'apreender' a relação entre as variáveis preditoras
# - y_train: Uma parte também de treino do modelo, mas somente com as variáveis target, ou os valores que queremos prever
# - X_test: Uma parte para teste, onde o modelo irá exercer o aprendizado obtido com os arrays X_train e y_train, ou irá testar o que foi observado com os arrays de treino
# - y_test: Uma parte para avaliar a performance do modelo, y_test contém as saídas corretas que desejamos prever,e é usado para comparar com as predições feitas pelo modelo

# %%
#Import do modulo train_test_split 
from sklearn.model_selection import train_test_split

#Divisão do dataset seguindo a proporção 70/30 (70% para treino e 30% para teste)
X_trainset, X_testset, y_trainset, y_testset = train_test_split(Xstd, y, test_size=0.3, random_state=3)

# %% [markdown]
# O algoritmo escolhido foi o SGDClassifer (Stochastic Gradient Descent Classifier), foi escolhido seguindo o flowchart da biblioteca Scikit-Learn disponível neste link (https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html)
#
# Como não conheço o algoritmo, não sabia como 'regular' os parâmetros do mesmo pra obter um melhor resultado, então testei alguns ao mesmo tempo e escolhi o que se saiu melhor (por uma margem pequena). Ainda sim, não fiquei satisfeito com o resultado, mas decidi deixar assim mesmo para não empacar no andamento da coisa

# %%
#Import do algoritmo SGDClassifier
from sklearn.linear_model import SGDClassifier
#clf = SGDClassifier(loss="hinge", penalty="l1", max_iter=6, n_jobs = -1, early_stopping= False)

#clfloss = SGDClassifier(loss="log", penalty="l1", max_iter=6, n_jobs = -1, early_stopping= False)

clfsqhinge = SGDClassifier(loss="squared_hinge", penalty="l1", max_iter=8, n_jobs = -1, early_stopping= False, warm_start= True)

#clfperceptron = SGDClassifier(loss="perceptron", penalty="l1", max_iter=6, n_jobs = -1, early_stopping= False)

#clfmodhuber = SGDClassifier(loss="modified_huber", penalty="l1", max_iter=6, n_jobs = -1, early_stopping= False)

# %%
#Treino do modelo
#clf.fit(X_trainset,y_trainset)

#clfloss.fit(X_trainset,y_trainset)

clfsqhinge.fit(X_trainset,y_trainset)

#clfperceptron.fit(X_trainset,y_trainset)

#clfmodhuber.fit(X_trainset,y_trainset)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='squared_hinge',
#        max_iter=8, n_iter=None, n_iter_no_change=5, n_jobs=-1,
#        penalty='l1', power_t=0.5, random_state=None, shuffle=True,
#        tol=None, validation_fraction=0.1, verbose=0, warm_start=True)

# %%
#Armazenando as predições de com dados de treino e dados de teste
#pTrain = clf.predict(X_trainset)
#pTest = clf.predict(X_testset)

#plossTrain = clfloss.predict(X_trainset)
#plossTest = clfloss.predict(X_testset)

psqhingeTrain = clfsqhinge.predict(X_trainset)
psqhingeTest = clfsqhinge.predict(X_testset)

#pptronTrain = clfperceptron.predict(X_trainset)
#pptronTest = clfperceptron.predict(X_testset)

#pmodhuberTrain = clfmodhuber.predict(X_trainset)
#pmodhuberTest = clfmodhuber.predict(X_testset)

# %% [markdown]
# #### Avaliação do desempenho do algoritmo
# Eu gostaria muito, muito mesmo de poder explicar com grande riqueza de detalhes o que acontece, passo a passo, bloco por bloco, as técnicas utilizadas e o por quê da utilização das mesmas, explicar os conceitos e etc.
#
# Mas infelizmente estou apenas molhando os pés no mar que é Machine Learning. É mais ou menos como saber que você não sabe nadar e estar entrando em um lago ou no mar, vc molha os pés, talvez entre até a altura da cintura na água, mas sabe que se passar daquele limite, provavelmente irá se afogar.
#
# Entretanto, só se aprende a nadar.... nadando, então bora!
#
# Existem diversas metricas para avaliação do desempenho de um modelo de ML, algumas generalistas, outras indicadas para certos tipos de algoritmos ou tipo de problema a ser resolvido.
# As que utilizarei aqui, são as metricas que foram abordadas no curso de Machine Learning c/ Python da Cognitive Class, tentarei explicar 'por cima' algumas dessas métricas, até como forma de estudo, para ajudar na fixação do conteúdo

# %% [markdown]
# Vale a pena destacar também alguns pontos importantes: Não houve nenhum tipo de análise própiamente dito, da distribuição dos dados, da correlação entre os mesmos e etc.
# As 'features' selecionadas para montagem do dataset 'fset' foram características que eu escolhi sem ter feito uma análise mais aprofundada dos dados, eu simplesmente escolhi.
#
# Normalmente a implementação de modelos de ML ocorre ao fim de uma análise exploratória dos dados, mas neste caso a implementação do algoritmo sem os devidos procedimentos preparatórios, é puramente a título de estudo e prática

# %%
#Import do módulo metrics da biblioteca sklearn
import sklearn.metrics as m

# %% [markdown]
# #### O índice Jaccard
# (Trecho retirado do notebook de regressão logística do curso Machine Learning with Python da Cognitiveclass)
#
# We can define jaccard as the size of the intersection divided by the size of the union of two label sets. If the entire set of predicted labels for a sample strictly match with the true set of labels, then the subset accuracy is 1.0; otherwise it is 0.0.
#
#
# Podemos definir o índice Jaccard como o tamanho da intersecção dividido pela união dos dois sets de labels. Se o set inteiro de labels previstas para uma amosta combina exatamente com o set de labels verdadeiro (no caso y_test), então a acurácia (precisão) é 1.0. Caso contrário é 0.0

# %% [markdown]
# Acabei descobrindo que o método .jaccard_similarity_score e .accuracy_score são bem parecidos, mas o método .jaccard_similarity_score é diferente para problemas de classificação multilabel

# %%
#print('Indice Jaccard p/ dados de Treino Loss = Hinge: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, pTrain)))
#print('Indice Jaccard p/ dados de Teste Loss = Hinge: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, pTest)))
#print('')
#print('Indice Jaccard p/ dados de Treino Loss = Log: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, plossTrain)))
#print('Indice Jaccard p/ dados de Teste Loss = Log: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, plossTest)))
#print('')
print('Indice Jaccard p/ dados de Treino Loss = Squared Hinge: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, psqhingeTrain)))
print('Indice Jaccard p/ dados de Teste Loss = Squared Hinge: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, psqhingeTest)))
#print('')
#print('Indice Jaccard p/ dados de Treino Loss = Perceptron: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, pptronTrain)))
#print('Indice Jaccard p/ dados de Teste Loss = Perceptron: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, pptronTest)))
#print('')
#print('Indice Jaccard p/ dados de Treino Loss = Modified Huber: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, pmodhuberTrain)))
#print('Indice Jaccard p/ dados de Teste Loss = Modified Huber: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, pmodhuberTest)))
# Out:
# Indice Jaccard p/ dados de Treino Loss = Squared Hinge: 0.737%
# Indice Jaccard p/ dados de Teste Loss = Squared Hinge: 0.737%

# %%
print('Erros de classificação das amostras Treino: {}'.format((y_trainset != psqhingeTrain).sum()),'\nAmostras de treino "y": {}'.format(y_trainset.shape[0]))
print('Erros de classificação das amostras Teste: {}'.format((y_testset != psqhingeTest).sum()),'\nAmostras de teste "y": {}'.format(y_testset.shape[0]))
# Out:
# Erros de classificação das amostras Treino: 557815
# Amostras de treino "y": 2118624
# Erros de classificação das amostras Teste: 239083
# Amostras de teste "y": 907983

# %% [markdown]
# #### Função Confusion Matrix
# Matriz confusão é uma outra métrica utilizada para avaliar a performance de um modelo de ML, onde são contablizados os números de resultados Positivos Verdadeiros, Falsos Positivos, Negativos Verdadeiros e Falsos negativos.
#
# A função abaixo que faz o plot da matriz confusão de forma mais amigável p/ leitura das informações foi retirada de um dos notebooks do curso de machine learning da Cognitiveclass, assim como o bloco logo em seguida, que faz a chamada a função

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
cnf_matrix = m.confusion_matrix(y_testset, psqhingeTest, labels = fset.estado_fisico.unique())
np.set_printoptions(precision=2)

print (m.classification_report(y_testset, psqhingeTest))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes= fset.estado_fisico.unique(), normalize= False,  title='Confusion matrix')
# Out:
# D:\Programas\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# D:\Programas\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# D:\Programas\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                precision    recall  f1-score   support
#
#  Ferido Grave       0.00      0.00      0.00     56935
#   Ferido Leve       0.50      0.47      0.48    172961
#         Ileso       0.80      0.94      0.86    616056
# ...

# %% [markdown]
# Não foi lá essas coisas o desempenho do algoritmo, pra não dizer outras coisas. Eu estava pronto pra aplicar o modelo, mas 72% de precisão me incomodava, bastante.
#
# Então decidi tentar outro algoritmo de classificação, um que eu já estivesse mais acostumado, independente do desempenho do mesmo, só por desencargo de consciência.
# E o candidato da vez era o Decision Trees

# %% [markdown]
# Basicamente, o Decision Trees busca organizar as informações de forma a diminuir o valor da Entropia. Entropia de forma simples, é o grau de incerteza sobre determinada informação. Quanto maior a entropia, menor a certeza sobre determinado dado, ou mais "desorganizado" está aquele dado.
#
# O algoritmo Decision Tree utiliza cálculos matemáticos afim de mensurar e diminuir o grau de entropia em dados, aumentando assim o ganho de informação. Assim que uma determinada observação tem sua entropia reduzida a zero, forma-se uma folha na árvore, e observações com as mesmas características passam a ser agrupadas nesta determinada folha. Enquanto as outras informações continuam sendo processadas e subdividindo-se em galhos e novas folhas.
# (é mais ou menos isso, mas é melhor vc pesquisar e ver as definições de como isso funciona)

# %%
from sklearn import tree
avere = tree.DecisionTreeClassifier()
avere.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# "Jesus é o jardineiro, e as áveres, somo nozes"

# %%
#Duas previsões, uma para os dados de treino e outra para os dados de teste
avereTE = avere.predict(X_testset)
avereTR = avere.predict(X_trainset)

# %%
print('Indice Jaccard p/ dados de Teste: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, avereTE)))
print('Indice Jaccard p/ dados de Treino: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, avereTR)))
# Out:
# Indice Jaccard p/ dados de Teste: 0.781%
# Indice Jaccard p/ dados de Treino: 0.999%

# %%
print('Erros de classificação das amostras Treino: {}'.format((y_trainset != avereTR).sum()),'\nAmostras de treino "y": {}'.format(y_trainset.shape[0]))
print('Erros de classificação das amostras Teste: {}'.format((y_testset != avereTE).sum()),'\nAmostras de teste "y": {}'.format(y_testset.shape[0]))
# Out:
# Erros de classificação das amostras Treino: 2353
# Amostras de treino "y": 2118624
# Erros de classificação das amostras Teste: 199078
# Amostras de teste "y": 907983

# %%
#78% é melhor que 72%, mas o que acontece se eu mexer um pouco nos parâmetros ?
avere = tree.DecisionTreeClassifier(criterion = 'entropy', min_samples_split=4)
avere.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=4,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Fazendo as previsões
avereTE = avere.predict(X_testset)
avereTR = avere.predict(X_trainset)

# %%
print('Indice Jaccard p/ dados de Teste: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, avereTE)))
print('Indice Jaccard p/ dados de Treino: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, avereTR)))
# Out:
# Indice Jaccard p/ dados de Teste: 0.783%
# Indice Jaccard p/ dados de Treino: 0.977%

# %%
print('Erros de classificação das amostras Treino: {}'.format((y_trainset != avereTR).sum()),'\nAmostras de treino "y": {}'.format(y_trainset.shape[0]))
print('Erros de classificação das amostras Teste: {}'.format((y_testset != avereTE).sum()),'\nAmostras de teste "y": {}'.format(y_testset.shape[0]))
# Out:
# Erros de classificação das amostras Treino: 48929
# Amostras de treino "y": 2118624
# Erros de classificação das amostras Teste: 197298
# Amostras de teste "y": 907983

# %% [markdown]
# Ganho de precisão baixo, mas ainda sim um ganho...
# Neste momento lembrei do Daniel Mendes, um dos instrutores da Data Science Academy comentando sobre métodos ensemble e o ótimo desempenho desses algoritmos, pesquisei 'ensemble' na documentação da biblioteca Scikit-Learn e logo nas sugestões apareceu 'RandomForest' que era um algoritmo que eu tinha curiosidade de aprender, e sabia que era baseado no conceito de árvores de decisão, pq não implementar e ver o desempenho ?

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#RUN FORREST,RUN!
forrest = RandomForestClassifier()
forrest.fit(X_trainset,y_trainset)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#Aqui as predições são armazenadas nas variáveis 'gump'
gumpTR = forrest.predict(X_trainset)
gumpTE = forrest.predict(X_testset)

# %%
print('Indice Jaccard p/ dados de Teste: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, gumpTE)))
print('Indice Jaccard p/ dados de Treino: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, gumpTR)))
# Out:
# Indice Jaccard p/ dados de Teste: 0.823%
# Indice Jaccard p/ dados de Treino: 0.992%

# %%
print('Erros de classificação das amostras Treino: {}'.format((y_trainset != gumpTR).sum()),'\nAmostras de treino "y": {}'.format(y_trainset.shape[0]))
print('Erros de classificação das amostras Teste: {}'.format((y_testset != gumpTE).sum()),'\nAmostras de teste "y": {}'.format(y_testset.shape[0]))
# Out:
# Erros de classificação das amostras Treino: 17401
# Amostras de treino "y": 2118624
# Erros de classificação das amostras Teste: 160741
# Amostras de teste "y": 907983

# %%
#Novamente, alterando alguns parâmetros para ver o resultado
forrest = RandomForestClassifier(criterion = 'entropy', min_samples_split=4)
forrest.fit(X_trainset,y_trainset)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=4,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#Aqui as predições são armazenadas nas variáveis 'gump'
gumpTR = forrest.predict(X_trainset)
gumpTE = forrest.predict(X_testset)

# %%
print('Indice Jaccard p/ dados de Teste: {:.3f}%'.format(m.jaccard_similarity_score(y_testset, gumpTE)))
print('Indice Jaccard p/ dados de Treino: {:.3f}%'.format(m.jaccard_similarity_score(y_trainset, gumpTR)))
# Out:
# Indice Jaccard p/ dados de Teste: 0.828%
# Indice Jaccard p/ dados de Treino: 0.971%

# %%
print('Erros de classificação das amostras Treino: {}'.format((y_trainset != gumpTR).sum()),'\nAmostras de treino "y": {}'.format(y_trainset.shape[0]))
print('Erros de classificação das amostras Teste: {}'.format((y_testset != gumpTE).sum()),'\nAmostras de teste "y": {}'.format(y_testset.shape[0]))
# Out:
# Erros de classificação das amostras Treino: 61195
# Amostras de treino "y": 2118624
# Erros de classificação das amostras Teste: 156082
# Amostras de teste "y": 907983

# %%
# Compute confusion matrix
cnf_matrix = m.confusion_matrix(y_testset, gumpTE, labels = fset.estado_fisico.unique())
np.set_printoptions(precision=2)

print (m.classification_report(y_testset, gumpTE))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes= fset.estado_fisico.unique(), normalize= False,  title='Confusion matrix')
# Out:
#                precision    recall  f1-score   support
#
#  Ferido Grave       0.38      0.17      0.23     56935
#   Ferido Leve       0.65      0.75      0.70    172961
#         Ileso       0.92      0.94      0.93    616056
# Lesões Graves       0.39      0.14      0.21      9579
#  Lesões Leves       0.67      0.67      0.67     34000
#         Morto       0.59      0.68      0.63     18452
#
#     micro avg       0.83      0.83      0.83    907983
#     macro avg       0.60      0.56      0.56    907983
#  weighted avg       0.81      0.83      0.82    907983
#
# Confusion matrix, without normalization
# [[129003  29866  11225   2453    383     31]
#  [ 29660 576729   2313   1897   5178    279]
#  [ 35849   8201   9459   3281    122     23]
#  [  1499   2157   1937  12499    174    186]
#  [  1661   7339    109    446  22823   1622]
#  [   376   1614     68    513   5620   1388]]

# %%
#Resetando os indices de rawdata e montando um novo dataset
rawdata.reset_index(inplace= True)
fset2 = rawdata[['br','km','causa_acidente','tipo_acidente','classificacao_acidente',
               'condicao_metereologica','tipo_pista','tracado_via','tipo_veiculo','marca',
               'ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo']].copy()

# %%
#Juntando todos os indices dos registros na variável f3
f1 = fset2.loc[fset2['estado_fisico'] == 'Não Informado'].index
f2 = fset2.loc[fset2['estado_fisico'] == 'Ignorado'].index
f3 = f1.append(f2)

# %%
#Dropando a coluna target
fset2.drop(labels= 'estado_fisico', axis= 1, inplace= True)

# %%
#Codificando os valores de X2 para valores numéricos e normalizando para o array X2std
X2 = fset2.values
X2[:,2] = Le_causa.transform(X2[:,2])
X2[:,3] = Le_tipo_acidente.transform(X2[:,3])
X2[:,4] = Le_class_acidente.transform(X2[:,4])
X2[:,5] = Le_clima.transform(X2[:,5])
X2[:,6] = Le_pista.transform(X2[:,6])
X2[:,7] = Le_tracado.transform(X2[:,7])
X2[:,8] = Le_veiculo.transform(X2[:,8])
Le_marca.fit(fset2.marca.unique())
X2[:,9] = Le_marca.transform(X2[:,9])
X2[:,11] = Le_envolvido.transform(X2[:,11])
X2[:,13] = Le_sexo.transform(X2[:,13])
X2std = std.transform(X2)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#fset2 recebe uma nova coluna estado_fisico apenas com as previsões do modelo forrest
fset2['estado_fisico'] = forrest.predict(X2std)

# %%
fset2.columns
# Out:
# Index(['br', 'km', 'causa_acidente', 'tipo_acidente', 'classificacao_acidente',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'tipo_veiculo',
#        'marca', 'ano_fabricacao_veiculo', 'tipo_envolvido', 'idade', 'sexo',
#        'estado_fisico'],
#       dtype='object')

# %%
rawdata.columns
# Out:
# Index(['level_0', 'index', 'reg_id', 'id', 'pesid', 'data_hora', 'dia_semana',
#        'horario', 'uf', 'br', 'km', 'municipio', 'causa_acidente',
#        'tipo_acidente', 'classificacao_acidente', 'sentido_via',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
#        'id_veiculo', 'tipo_veiculo', 'marca', 'ano_fabricacao_veiculo',
#        'tipo_envolvido', 'estado_fisico', 'idade', 'sexo', 'ilesos',
#        'feridos_leves', 'feridos_graves', 'mortos', 'latitude', 'longitude'],
#       dtype='object')

# %%
rawdata.iloc[:10,25]
# Out:
# 0    Ferido Leve
# 1    Ferido Leve
# 2    Ferido Leve
# 3    Ferido Leve
# 4          Ileso
# 5          Ileso
# 6          Ileso
# 7          Ileso
# 8          Ileso
# 9    Ferido Leve
# Name: estado_fisico, dtype: object

# %%
fset2.iloc[:10,14]
# Out:
# 0    Ferido Leve
# 1    Ferido Leve
# 2    Ferido Leve
# 3    Ferido Leve
# 4          Ileso
# 5          Ileso
# 6          Ileso
# 7          Ileso
# 8          Ileso
# 9    Ferido Leve
# Name: estado_fisico, dtype: object

# %%
#Loop for que faz o update das informações no dataset rawdata
#Execução demorada, executei uma vez e em seguida salvei o dataset modificado para evitar executar novamente
#Tempo estimado de execução: 30~40 minutos.


#z=0
with pd.option_context('max_column',45): #Usado na construção do loop para ver cada registro
    for i in f3:
        #print('valor i: ',i)
        #display(rawdata.iloc[[i]])
        #display(fset2.iloc[[i]])
        #z = z+1
        #if (z == 3):
        #    break
        rawdata.iloc[i,25] = fset2.iloc[i,14]

# %%
#Tempo estimado de execução: 3~4 segundos.
for i in f3:
    rawdata.at[i,'estado_fisico'] = fset2.at[i,'estado_fisico']

# %%
f3
# Out:
# Int64Index([2480423, 2480449, 2480481, 2480515, 2480553, 2480559, 2480577,
#             2485343, 2485349, 2485397,
#             ...
#             2753693, 2753771, 2753802, 2753810, 2753824, 2753849, 2753857,
#             2753859, 2753878, 2753914],
#            dtype='int64', length=25243)

# %%
#deixa as testemunas assim, pq pra cada testemunha, teve pelo menos uma vítima

# %%
#Salvando as modificações feitas no loop for
#rawdata.to_csv('acidentes2.csv',index= False)

# %%
#data = pd.read_csv('acidentes2.csv', low_memory= False, parse_dates = ['data_hora'])
#data.drop(labels=['level_0','index'],axis= 1, inplace= True)

# %%
#data.info()

# %%
#data['id'] = data['id'].astype(int)
#data['pesid'] = data['pesid'].astype(int)

# %%
vitimas = pd.get_dummies(rawdata['estado_fisico'])

# %%
rawdata.drop(labels=['level_0','ilesos','feridos_leves','feridos_graves','mortos'],axis= 1, inplace = True)

# %%
rawdata = pd.concat([rawdata,vitimas], axis= 1, join='outer')

# %%
rawdata.rename(mapper={'Ileso':'ilesos','Ferido Leve':'feridos_leves', 'Ferido Grave':'feridos_graves','Lesões Leves':'lesionados_leves',
                    'Lesões Graves':'lesionados_graves','Morto':'mortos'}, axis= 1, inplace= True)

# %%
rawdata['estado_fisico'].value_counts()
# Out:
# Ileso            2065159
# Ferido Leve       581679
# Ferido Grave      191797
# Lesões Leves      116598
# Morto              63558
# Lesões Graves      33059
# Name: estado_fisico, dtype: int64

# %%
print('Ileso: ',rawdata.ilesos.sum())
print('Ferido Leve: ',rawdata.feridos_leves.sum())
print('Ferido Grave: ',rawdata.feridos_graves.sum())
print('Lesões Leves: ',rawdata.lesionados_leves.sum())
print('Morto: ',rawdata.mortos.sum())
print('Lesões Graves: ',rawdata.lesionados_graves.sum())
# Out:
# Ileso:  2065159
# Ferido Leve:  581679
# Ferido Grave:  191797
# Lesões Leves:  116598
# Morto:  63558
# Lesões Graves:  33059

# %%
rawdata.isnull().sum()
# Out:
# index                           0
# reg_id                          0
# id                              0
# pesid                           0
# data_hora                       0
# dia_semana                      0
# horario                         0
# uf                              0
# br                              0
# km                              0
# municipio                       0
# causa_acidente                  0
# tipo_acidente                   0
# classificacao_acidente          0
# sentido_via                     0
# condicao_metereologica          0
# tipo_pista                      0
# tracado_via                     0
# uso_solo                        0
# id_veiculo                      0
# tipo_veiculo                    0
# marca                           0
# ano_fabricacao_veiculo          0
# tipo_envolvido                  0
# estado_fisico                   0
# idade                           0
# sexo                            0
# ...
